# %% [markdown]
# <a href="https://colab.research.google.com/github/vkkumar-cse/DAA-EXPERIMENTS/blob/main/DAA_exp_5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


def partition(arr, low, high):
    pivot = arr[high]

    i = low

    for j in range(low, high):
        if arr[j] <= pivot:
            arr[i], arr[j] = arr[j], arr[i]
            i += 1

    arr[i], arr[high] = arr[high], arr[i]

    return i


def quickselect(arr, low, high, k):

    if low <= high:

        pivot = partition(arr, low, high)

        if pivot == k:
            return arr[pivot]

        elif pivot > k:
            return quickselect(arr, low, pivot - 1, k)

        else:
            return quickselect(arr, pivot + 1, high, k)


# Generate Random Array
arr = [random.randint(1, 10000) for _ in range(1000)]

n = len(arr)

print("Array Size:", n)

# Minimum
minimum = quickselect(arr.copy(), 0, n-1, 0)

# Maximum
maximum = quickselect(arr.copy(), 0, n-1, n-1)

# Median
median = quickselect(arr.copy(), 0, n-1, n//2)

print("Minimum :", minimum)
print("Maximum :", maximum)
print("Median :", median)
# Out:
# Array Size: 1000
# Minimum : 5
# Maximum : 9960
# Median : 4961
